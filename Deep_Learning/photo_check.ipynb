# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhamk05/python_projects/blob/main/Deep_Learning/photo_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 4))
for i in range(7):
    plt.subplot(1, 7, i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f'Label: {y_train[i]}')
    plt.axis('off')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7851 - loss: 6.0470 - val_accuracy: 0.8987 - val_loss: 0.3894
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9086 - loss: 0.3414 - val_accuracy: 0.9237 - val_loss: 0.3096
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9398 - loss: 0.2210 - val_accuracy: 0.9394 - val_loss: 0.2276
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9482 - loss: 0.1866 - val_accuracy: 0.9522 - val_loss: 0.1861
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9565 - loss: 0.1542 - val_accuracy: 0.9524 - val_loss: 0.1965

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9442 - loss: 0.2128
# Test Accuracy: 0.9532

# %%
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2, verbose=1)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9616 - loss: 0.1373 - val_accuracy: 0.9603 - val_loss: 0.1529
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9698 - loss: 0.1104 - val_accuracy: 0.9646 - val_loss: 0.1386
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9717 - loss: 0.1011 - val_accuracy: 0.9660 - val_loss: 0.1407
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9740 - loss: 0.0943 - val_accuracy: 0.9645 - val_loss: 0.1568
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9758 - loss: 0.0878 - val_accuracy: 0.9650 - val_loss: 0.1615

# %%
import numpy as np
predictions = model.predict(x_test[:5])
plt.figure(figsize=(20 ,7))
for i in range(5):
    plt.subplot(1, 7, i+1)
    plt.imshow(x_test[i], cmap='gray')
    plt.title(f'Pred: {np.argmax(predictions[i])}, True: {y_test[i]}')
    plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step

# %%
plt.imshow(x_test[1])
plt.show()
